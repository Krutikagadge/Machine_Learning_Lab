# %% [markdown]
# ## LINEAR REGRESSION

# %% [markdown]
# ### Krutika Gadge-22070521178

# %%
 CONNECT DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
file_path = '/content/drive/MyDrive/ML_PRACTICALS_SEM7/LR_Dataset.csv'
data=pd.read_csv(file_path)
data.head()
# Out:
#    AREA    PRICE
# 0    45  2250000
# 1    60  3100000
# 2    75  3850000
# 3    90  4620000
# 4   100  5020000

# %%
# LINEAR REGRESSION
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=data[['AREA']]
y=data['PRICE']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,
                                               random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([8125430.62200957, 3027344.49760765, 5576387.55980861])

# %%
#accuracy
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9983408458069157

# %%
#graph for predictions
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.xlabel('AREA')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
import pandas as pd
import numpy as np
file_path = '/content/drive/MyDrive/ML_PRACTICALS_SEM7/LR_Dataset2.csv'
data=pd.read_csv(file_path)
data.head()
# Out:
#    AREA    PRICE
# 0    45  2250000
# 1    60  3100000
# 2    75  3850000
# 3    90  4620000
# 4   100  5020000

# %%
# LINEAR REGRESSION
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=data[['AREA']]
y=data['PRICE']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
#accuracy
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.04204916151784599

# %%
#graph for predictions
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.xlabel('AREA')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
import pandas as pd
import numpy as np
file_path = '/content/drive/MyDrive/ML_PRACTICALS_SEM7/Housing.csv'
data=pd.read_csv(file_path)
data.head()
# Out:
#       PRICE  AREA
# 0  13300000  7420
# 1  12250000  8960
# 2  12250000  9960
# 3  12215000  7500
# 4  11410000  7420

# %%
x=data[['AREA']]
y=data['PRICE']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
#accuracy
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.2583140345296001

# %%
#graph for predictions
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.xlabel('AREA')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')
